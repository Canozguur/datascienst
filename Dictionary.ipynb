# %%
my_data = {"name":"CAN", "age": 25}

# %%
my_data
# Out:
# {'name': 'CAN', 'age': 25}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['CAN', 25])

# %%
my_data["height"] = 1.7
my_data
# Out:
# {'name': 'CAN', 'age': 25, 'height': 1.7}

# %%
my_data.update({"height": 1.75})
my_data
# Out:
# {'name': 'CAN', 'age': 25, 'height': 1.75}

# %%
my_data.items()
# Out:
# dict_items([('name', 'CAN'), ('age', 25)])

# %% [markdown]
# # Copy a dictionary

# %%
new_dict = my_data.copy()
new_dict
# Out:
# {'name': 'CAN', 'age': 25, 'height': 1.75}

# %% [markdown]
# ## remove element

# %%
my_data.pop("name")
# Out:
# 'CAN'

# %%
print(my_data) 
print(new_dict)
# Out:
# {'age': 25, 'height': 1.75}
# {'name': 'CAN', 'age': 25, 'height': 1.75}

# %%
del my_data['height']

# %%
my_data
# Out:
# {}

# %%
age = 25
if age >= 18:
    print("you are adult")
elif age < 18:
    print("you are kid")
# Out:
# you are adult

# %% [markdown]
# ## For Loop

# %%
countries = ["Turkey", "Spain", "China"]
for i ,country in enumerate(countries):
    print(i, country)
# Out:
# 0 Turkey
# 1 Spain
# 2 China

# %%
new_dict
# Out:
# {'name': 'CAN', 'age': 25, 'height': 1.75}

# %%
for key ,value in new_dict.items():
    print(key, value)
# Out:
# name CAN
# age 25
# height 1.75

# %% [markdown]
# ## Function

# %%
def sum_values(a,b):
    x = a + b
    return x

# %%
sum_values(4,5)
# Out:
# 9

# %% [markdown]
# # MODULE

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/canozgur'

# %%
os.listdir()
# Out:
# ['.config',
#  'kaan procejt',
#  'Music',
#  'new Folder',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  'anaconda_projects',
#  'Untitled.ipynb',
#  '.zshrc',
#  'new Folderr',
#  'first-app',
#  '.templateengine',
#  '.arduinoIDE',
#  '.local',
#  'Pictures',
#  '.zprofile',
#  '.nuget',
#  'Dictionary.ipynb',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  '.oracle_jre_usage',
#  '.IdentityService',
#  'README.md',
#  '.android',
#  '.cocoapods',
#  '.cups',
#  'PycharmProjects',
#  'Public',
#  '.idlerc',
#  '.tcshrc',
#  '.virtual_documents',
#  '.anaconda',
#  'Movies',
#  '.dotnet',
#  'Applications',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  '.npm',
#  'Documents',
#  '.git',
#  '.mono',
#  '.vscode',
#  '.bash_profile',
#  '.swiftpm',
#  'Downloads',
#  '.continuum',
#  '.gitconfig',
#  '.zsh_sessions',
#  'Kitap(AutoRecovered).xlsx',
#  '.conda']

# %%
os.makedirs("new Folderr")
