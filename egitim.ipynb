# %%
x = 23
y = "can"
z = [1,2,3]
a = True
b = (1,2,3)
c = {25:"can",27:"cansu"}

# %%
print(type(x))
print(type(y))
print(type(z))
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'bool'>
# <class 'tuple'>
# <class 'dict'>

# %%
string = "hello world!!!"
sayisal = "25"
print(string.capitalize())
print(string.islower())
print(sayisal.isdigit())
type(int(sayisal))
# Out:
# Hello world!!!
# True
# True
# int
