# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame([[1,2,3],[2,1,3]],
    index = ["A","B"]
)

# %%
data
# Out:
#    0  1  2
# A  1  2  3
# B  2  1  3

# %%
data.loc["A"]
data.loc["C"]
data
# Out:
# 0    3
# Name: C, dtype: int64

# %%
veri = pd.Series(np.random.randn(8),
                index= [["a","a","a","b","b","b","c","c"],
                       [1,2,3,1,2,3,1,2]])
veri
# Out:
# a  1    0.234678
#    2    0.234752
#    3    0.724804
# b  1   -0.986634
#    2   -0.815475
#    3   -0.707355
# c  1    0.255083
#    2   -1.354254
# dtype: float64

# %%
veri.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
veri["a":"b"]
# Out:
# a  1    0.234678
#    2    0.234752
#    3    0.724804
# b  1   -0.986634
#    2   -0.815475
#    3   -0.707355
# dtype: float64

# %%
veri.loc[["a","c"]]
# Out:
# a  1    0.234678
#    2    0.234752
#    3    0.724804
# c  1    0.255083
#    2   -1.354254
# dtype: float64

# %%
veri.loc[:,1]
# Out:
# a    0.234678
# b   -0.986634
# c    0.255083
# dtype: float64

# %%
veri.unstack()
# Out:
#           1         2         3
# a  0.234678  0.234752  0.724804
# b -0.986634 -0.815475 -0.707355
# c  0.255083 -1.354254       NaN

# %%
veri.unstack().stack()
# Out:
# a  1    0.234678
#    2    0.234752
#    3    0.724804
# b  1   -0.986634
#    2   -0.815475
#    3   -0.707355
# c  1    0.255083
#    2   -1.354254
# dtype: float64

# %%
vs = pd.DataFrame(np.arange(12).reshape(4,3),
                 index=[["a","a","b","b"],[1,2,1,2]],
                        columns=[["say","say","soz"],
                                ["mat","fiz","edb"]])
vs
# Out:
#     say     soz
#     mat fiz edb
# a 1   0   1   2
#   2   3   4   5
# b 1   6   7   8
#   2   9  10  11

# %%
vs.index.names= ["sinif","sinav"]
vs.columns.names=["alan","ders"]

# %%
vs
# Out:
# alan        say     soz
# ders        mat fiz edb
# sinif sinav
# a     1       0   1   2
#       2       3   4   5
# b     1       6   7   8
#       2       9  10  11

# %%
vs["say"]
# Out:
# ders         mat  fiz
# sinif sinav
# a     1        0    1
#       2        3    4
# b     1        6    7
#       2        9   10

# %%
vs.swaplevel("sinif","sinav")
# Out:
# alan        say     soz
# ders        mat fiz edb
# sinav sinif
# 1     a       0   1   2
# 2     a       3   4   5
# 1     b       6   7   8
# 2     b       9  10  11

# %%
vs.sort_index(level=1)
# Out:
# alan        say     soz
# ders        mat fiz edb
# sinif sinav
# a     1       0   1   2
# b     1       6   7   8
# a     2       3   4   5
# b     2       9  10  11

# %%
vs.groupby(level="sinav").sum()
# Out:
# alan  say     soz
# ders  mat fiz edb
# sinav
# 1       6   8  10
# 2      12  14  16

# %%
vs.groupby(level= "alan",axis=1).sum()
# Out:
# /var/folders/nn/fmmg6g2d0lg8mt_0mvywycv80000gn/T/ipykernel_23518/2221920076.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   vs.groupby(level= "alan",axis=1).sum()
# alan         say  soz
# sinif sinav
# a     1        1    2
#       2        7    5
# b     1       13    8
#       2       19   11

# %%
veri = pd.DataFrame({"x":range(8),
                    "y":range(8,0,-1),
                    "a":["bir","bir","bir","bir","iki","iki","iki","iki"],
                    "b":[0,1,2,3,0,1,2,3]})

# %%
veri
# Out:
#    x  y    a  b
# 0  0  8  bir  0
# 1  1  7  bir  1
# 2  2  6  bir  2
# 3  3  5  bir  3
# 4  4  4  iki  0
# 5  5  3  iki  1
# 6  6  2  iki  2
# 7  7  1  iki  3

# %%
veri2 = veri.set_index(["a","b"])
#verideki a,b yi index olarak atiyor

# %%
veri2
# Out:
#        x  y
# a   b
# bir 0  0  8
#     1  1  7
#     2  2  6
#     3  3  5
# iki 0  4  4
#     1  5  3
#     2  6  2
#     3  7  1

# %%
veri3 = veri.set_index(["a","b"],drop = False)
veri3
#bu sayede drop false ile veriden dusmedi
# Out:
#        x  y    a  b
# a   b
# bir 0  0  8  bir  0
#     1  1  7  bir  1
#     2  2  6  bir  2
#     3  3  5  bir  3
# iki 0  4  4  iki  0
#     1  5  3  iki  1
#     2  6  2  iki  2
#     3  7  1  iki  3

# %%
veri2.reset_index()
# Out:
#      a  b  x  y
# 0  bir  0  0  8
# 1  bir  1  1  7
# 2  bir  2  2  6
# 3  bir  3  3  5
# 4  iki  0  4  4
# 5  iki  1  5  3
# 6  iki  2  6  2
# 7  iki  3  7  1

# %%
veri3.loc["bir",0]
# Out:
# x      0
# y      8
# a    bir
# b      0
# Name: (bir, 0), dtype: object
