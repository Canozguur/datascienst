# %%
import pandas as pd
import numpy as np

# %%
book_data = pd.read_csv("Amazon_BestSelling_Books_500.csv")

# %%
book_data.head(3)
# Out:
#    Rank                Title           Author     Category  \
# 0     1  The Let Them Theory      Mel Robbins  Non-Fiction
# 1     2     The Dinner Party  Freida McFadden      Fiction
# 2     3    Project Hail Mary        Andy Weir      Fiction
#
#                 Sub-Genre     Format  Price (USD)  Rating   Reviews  \
# 0               Self-Help  Paperback        14.99     4.7   98000.0
# 1  Psychological Thriller  Paperback        11.69     4.3    1800.0
# 2         Science Fiction  Paperback        12.99     4.8  130000.0
#
#    Weeks on List             Publisher  Year Published               ISBN  \
# 0           52.0             Hay House          2024.0  978-1-13278-859-4
# 1           12.0  Sourcebooks Landmark          2025.0  978-3-76237-716-0
# 2          108.0      Ballantine Books          2021.0  978-4-30379-320-5
#
#    Amazon BSR Amazon URL
# 0       112.0       View
# 1       175.0       View
# 2        64.0       View

# %%
book_data.nunique()
# Out:
# Rank              500
# Title             500
# Author            168
# Category            2
# Sub-Genre          48
# Format              5
# Price (USD)       439
# Rating             15
# Reviews           480
# Weeks on List      73
# Publisher          56
# Year Published     21
# ISBN              500
# Amazon BSR        486
# Amazon URL          1
# dtype: int64

# %%
book_data.groupby("Format").max()
# Out:
#                 Rank               Title        Author     Category  \
# Format
# Audiobook        490      World and Rain       various  Non-Fiction
# Board Book       496       Weakness Code  Tomi Adeyemi  Non-Fiction
# Hardcover        500      World and Bone       various  Non-Fiction
# Kindle Edition   499       World Unbound       various  Non-Fiction
# Paperback        498  Window and Thunder       various  Non-Fiction
#
#                  Sub-Genre  Price (USD)  Rating   Reviews  Weeks on List  \
# Format
# Audiobook       YA Romance        34.09     4.9   43995.0           53.0
# Board Book      YA Romance        14.97     4.8   37524.0           46.0
# Hardcover       YA Romance        29.95     5.0   87363.0         1200.0
# Kindle Edition  YA Romance        12.49     5.0   41844.0           48.0
# Paperback       YA Romance        24.99     5.0  220000.0          400.0
#
#                 Publisher  Year Published               ISBN  Amazon BSR  \
# Format
# Audiobook       Zondervan          2026.0  978-9-68226-186-8      8600.0
# Board Book      Zondervan          2026.0  978-9-73997-140-5      9310.0
# Hardcover       Zondervan          2026.0  978-9-98686-656-6      9475.0
# Kindle Edition  Zondervan          2026.0  978-9-90272-182-8      9600.0
# Paperback       Zondervan          2026.0  978-9-99727-823-0      8974.0
#
#                Amazon URL
# Format
# Audiobook            View
# Board Book           View
# Hardcover            View
# Kindle Edition       View
# Paperback            View

# %%
sample_data = book_data.sample(frac=0.2)

# %%
print(book_data.shape)
print(sample_data.shape)
# Out:
# (500, 15)
# (100, 15)

# %%
#concat iki data seti birlestirmeye yarar
new_data_set = pd.concat([sample_data,book_data])
new_data_set.shape
# Out:
# (600, 15)

# %%
data = book_data[["Rank","Author","Category","Sub-Genre","Format","Rating","Publisher"]]

# %%
data.sort_values("Rating",ascending=False)
# Out:
#      Rank                Author     Category            Sub-Genre  \
# 207   208           Dean Koontz      Fiction               Horror
# 289   290        Susanna Clarke      Fiction   Paranormal Romance
# 403   404      Ta-Nehisi Coates  Non-Fiction     Personal Finance
# 119   120        Virginia Evans      Fiction         Cozy Mystery
# 330   331        Jonathan Haidt  Non-Fiction     Celebrity Memoir
# ..    ...                   ...          ...                  ...
# 310   311           Joyce Meyer  Non-Fiction            Self-Help
# 451   452    Arianna Huffington  Non-Fiction     Personal Finance
# 79     80            Seth Godin  Non-Fiction  Activity / Coloring
# 65     66  Doris Kearns Goodwin  Non-Fiction       Cooking / Food
# 393   394      Malcolm Gladwell  Non-Fiction     Personal Finance
#
#              Format  Rating                   Publisher
# 207  Kindle Edition     5.0                   Doubleday
# 289       Hardcover     5.0              Flatiron Books
# 403       Hardcover     5.0                    Park Row
# 119       Paperback     5.0  Entangled: Red Tower Books
# 330       Hardcover     5.0                Rodale Books
# ..              ...     ...                         ...
# 310       Paperback     3.7        Lioncrest Publishing
# 451       Paperback     3.7                   Hay House
# 79        Audiobook     3.7                   Tor Books
# 65        Hardcover     3.7               Little, Brown
# 393       Paperback     3.6                       Knopf
#
# [500 rows x 7 columns]

# %% [markdown]
# ## Merge

# %%
test_data_1 = pd.DataFrame({"Sinif":["A","B","C","D"],
              "Not" : ["40","80","70","90"]
             })
test_data_1
# Out:
#   Sinif Not
# 0     A  40
# 1     B  80
# 2     C  70
# 3     D  90

# %%
test_data_2 = pd.DataFrame({"Sinif":["A","B","C","E"],
              "ogrenci_adi" : ["Can","Buse","Pelin","Semih"]
             })
test_data_2
# Out:
#   Sinif ogrenci_adi
# 0     A         Can
# 1     B        Buse
# 2     C       Pelin
# 3     E       Semih

# %%
#indicator nasil birlestiklerini anlatiyor
test_data_1.merge(test_data_2, on ="Sinif",how="outer",indicator=True)
# Out:
#   Sinif  Not ogrenci_adi      _merge
# 0     A   40         Can        both
# 1     B   80        Buse        both
# 2     C   70       Pelin        both
# 3     D   90         NaN   left_only
# 4     E  NaN       Semih  right_only

# %%
data_1 = data.query("Author == 'Dean Koontz' & Format =='Paperback'")

# %%
data_2 = data.query("Author == 'Dean Koontz' & Format =='Hardcover'")

# %%
# Merge icinde on hangi data uzerinden merge edilecegi belirler
data_1.merge(data_2,on="Author")
# Out:
#    Rank_x       Author Category_x      Sub-Genre_x   Format_x  Rating_x  \
# 0     284  Dean Koontz    Fiction     Cozy Mystery  Paperback       4.2
# 1     468  Dean Koontz    Fiction  Science Fiction  Paperback       4.7
#
#     Publisher_x  Rank_y Category_y        Sub-Genre_y   Format_y  Rating_y  \
# 0      Park Row     435    Fiction  Crime / Detective  Hardcover       4.6
# 1  Anchor Books     435    Fiction  Crime / Detective  Hardcover       4.6
#
#         Publisher_y
# 0  Simon & Schuster
# 1  Simon & Schuster

# %%
pd.concat([data_1,data_2])
# Out:
#      Rank       Author Category          Sub-Genre     Format  Rating  \
# 283   284  Dean Koontz  Fiction       Cozy Mystery  Paperback     4.2
# 467   468  Dean Koontz  Fiction    Science Fiction  Paperback     4.7
# 434   435  Dean Koontz  Fiction  Crime / Detective  Hardcover     4.6
#
#             Publisher
# 283          Park Row
# 467      Anchor Books
# 434  Simon & Schuster
